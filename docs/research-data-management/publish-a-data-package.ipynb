# %% [markdown]
# # Publish a Data Package
#
# ## What is Open Research Data (ORD)?
#
# **"Open Research Data" means that your dataset is publicly available for unrestricted download and use.**
#
# The SNSF [expects](http://www.snf.ch/en/theSNSF/research-policies/open_research_data/Pages/default.aspx) data generated by funded projects to be published as ORD. Eawag encourages publishing Open Research Data as it reflects positively on scientific credibility and contributes to the efficiency of scientific research.
#
# Eawag provides the Open Research Data repository [**ERIC/open**](https://opendata.eawag.ch) for its researchers. ERIC/open adheres to the [FAIR Principles](https://opendata.eawag.ch/about) and meets the requirements of SNSF, other funding sources, and journals requiring data to be published as ORD.

# %% [markdown]
# (publish-data-package)=
# ## How can I publish my data as Open Research Data in four easy steps?
#
# ### 1. Create a data package and upload it to **ERIC/internal**
#
# Most likely, you have already done this or are planning to, as Eawag [directive 19-03](https://www.internal.eawag.ch/fileadmin_intranet/intranet/informatik/datenman/rdm/directive_archiving_of_researchdata.pdf) (*{octicon}`alert-fill;1em;sd-text-danger` only accessible from Eawag intranet*) requires storing data that supports any publications.
#
# ```{note}
# If you haven't done this before, please consult the [Quickstart-Guide](quickstart-guide).
# ```
#
# ```{warning}
# [ERIC/internal](https://data.eawag.ch) can only be accessed within the Eawag network. If outside, use VPN to connect. If not in the Eawag network, you will be redirected to **ERIC/open**, where uploads are not possible.
# ```
#
#
# ### 2. Quality-check your data package
#
# The content and presentation of your published dataset reflect the quality of your scientific work. Ensure you have followed the [Eawag guide for publishing and archiving research data](research-data-publishing-guide) for optimal data preparation and organization.
#
#
#
# ### 3. Permission-check your data package
#
# **Thoroughly verify** that you have the right to publish all the information in your **Data Package**. Consider the following:
#
# - [Personal data](https://www.admin.ch/opc/en/classified-compilation/19920153/index.html#a3)
# - [Creative works](https://www.admin.ch/opc/en/classified-compilation/19920251/index.html#a2), such as text, maps, drawings, or computer programs that you do not have the rights to publish
# - Data obtained under licensing conditions prohibiting redistribution
# - Data involving collaborators who may not agree to the publication
# - Data your group plans to exploit in the future
#
# ```{note}
# You can **exclude files** that you uploaded to ERIC/internal **from a data publication** by informing [rdm@eawag.ch](mailto:rdm@eawag.ch).
# ```

# %%
# This cell encodes the email text do be copied to the rdm markdown link:
import urllib
from textwrap import dedent

def generate_email_link(body, subject="Data Publication", email="rdm@eawag.ch"):
    body = dedent(body).rstrip("\n").lstrip("\n")
    print(f"[{email}](mailto:rdm@eawag.ch?subject={urllib.parse.quote(subject)}&body={urllib.parse.quote(body)})")


generate_email_link(
    """
    Dear RDM team,
    
    I would like to publish the data package: "YOUR PACKAGE NAME OR URL HERE"
    I will do not yet have a DOI and will need one. / I already have a DOI: "YOUR DOI HERE"
    I have attached the filled in checklist.
    
    ANY OTHER INFORMATION YOU WANT TO GIVE US.
    
    Thank you,
    YOUR NAME
        """
)
# Out:
# [rdm@eawag.ch](mailto:rdm@eawag.ch?subject=Data%20Publication&body=Dear%20RDM%20team%2C%0A%0AI%20would%20like%20to%20publish%20the%20data%20package%3A%20%22YOUR%20PACKAGE%20NAME%20OR%20URL%20HERE%22%0AI%20will%20do%20not%20yet%20have%20a%20DOI%20and%20will%20need%20one.%20/%20I%20already%20have%20a%20DOI%3A%20%22YOUR%20DOI%20HERE%22%0AI%20have%20attached%20the%20filled%20in%20checklist.%0A%0AANY%20OTHER%20INFORMATION%20YOU%20WANT%20TO%20GIVE%20US.%0A%0AThank%20you%2C%0AYOUR%20NAME)

# %% [markdown]
# ### 4. Notify the Eawag Research Data Management team
#
# 1. Download the [**Data publishing checklist** (PDF)](https://data.eawag.ch/dataset/checklist-for-publishing-data-packages-at-eawag) (*{octicon}`alert-fill;1em;sd-text-danger` only accessible from Eawag intranet*) and tick the boxes.
#
# ```{tip}
# Download and open in a PDF reader. Browser PDF readers usually don’t allow checkbox interaction.
# ```
#
# 2. Send the checklist to [rdm@eawag.ch](mailto:rdm@eawag.ch?subject=Data%20Publication&body=Dear%20RDM%20team%2C%0A%0AI%20would%20like%20to%20publish%20the%20data%20package%3A%20%22YOUR%20PACKAGE%20NAME%20OR%20URL%20HERE%22%0AI%20will%20do%20not%20yet%20have%20a%20DOI%20and%20will%20need%20one.%20/%20I%20already%20have%20a%20DOI%3A%20%22YOUR%20DOI%20HERE%22%0AI%20have%20attached%20the%20filled%20in%20checklist.%0A%0AANY%20OTHER%20INFORMATION%20YOU%20WANT%20TO%20GIVE%20US.%0A%0AThank%20you%2C%0AYOUR%20NAME) (this link contains an email template).
#
# You will receive a notification when your **Data Package** is published, along with the DOI.
